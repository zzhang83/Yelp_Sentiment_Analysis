# %%
import sqlite3
import csv
import pandas as pd

conn = sqlite3.connect('yelp.db')
c = conn.cursor()

# %% [markdown]
# ### Look at the review data

# %%
a = pd.read_csv('data/review_subset.csv')

# %%
for i, key in enumerate(a.columns):
    print(i, key)

# %% [markdown]
# ### Look at the business data

# %%
pd.read_csv('data/business_data2.csv')

# %%
pd.read_csv('data/income_zipcode.csv')

# %% [markdown]
# # Create database structure
# 1. include users, business, income, review fact table
# 2. star schema

# %%
def create_database(conn):
    c = conn.cursor()

    c.execute('''DROP TABLE IF EXISTS business''')
    c.execute('''DROP TABLE IF EXISTS users''')
    c.execute('''DROP TABLE IF EXISTS income''')
    c.execute('''DROP TABLE IF EXISTS states''')
    c.execute('''DROP TABLE IF EXISTS review_fact_table''')
    
    c.execute('''
            CREATE TABLE users(
                user_id VARCHAR PRIMARY KEY, 
                review_count int,
                yelping_since DATE,
                average_stars REAL,
                UNIQUE(user_id))''')
    
    c.execute('''
            CREATE TABLE business(
                b_id VARCHAR,
                categories text,
                city text,
                is_open int,
                latitude REAL,
                longitude REAL,
                name text,
                postal_code REAL,
                pricerange int,
                review_count int,
                b_stars REAL,
                state text,
                PRIMARY KEY(b_id)
                UNIQUE(b_id) )''')
    
    c.execute('''
            CREATE TABLE income(
                zipcode INTEGER PRIMARY KEY,
                county text,
                state text, 
                avg_income REAL)
                ''')
    

    
    #create fact_table
    c.execute('''
        CREATE TABLE review_fact_table(
            review_id VARCHAR,
            user_id VARCHAR,
            business_id VARCHAR,
            zipcode int,
            review text,
            r_stars REAL,
            r_date DATE,
            PRIMARY KEY (review_id),
            FOREIGN KEY (user_id) REFERENCES users(user_id), 
            FOREIGN KEY (zipcode) REFERENCES income(zipcode),
            FOREIGN KEY (business_id) REFERENCES business(b_id))''')
    # Commit changes
    conn.commit()
# Create the database   
create_database(conn)

# %% [markdown]
# # Populate database
# 1. Users table from user_data.csv
# 2. Business table from business_data.csv
# 3. income table from income_data.csv
# 4. review_fact_table table from review_data2.csv

# %%
def populate_database(conn):    
    #reader = csv.reader(open('review_data2.csv', encoding='latin1'))
    reader = csv.reader(open('data/business_data2.csv', encoding='latin1'))

    
    income_dict = {}
    income_id = 0
    
    next(reader, None)
    for row in reader:
        row = [item.lower() for item in row]   
        # business table
        try:
            c.execute('''
                INSERT INTO business(b_id,
                                    categories,
                                    city,
                                    is_open,
                                    latitude,
                                    longitude,
                                    name,
                                    postal_code,
                                    pricerange,
                                    review_count,
                                    b_stars,
                                    state)VALUES(?,?,?,?,?,?,?,?,?,?,?,?)''',
                      (row[0],row[1],row[2],row[3],row[4],row[5],row[6],row[7],row[8],row[9],row[10],row[11]))
        except sqlite3.Error as e:
            print("business, insert error:", e.args[0])
    conn.commit()
              
   



    # Income table    
    reader = csv.reader(open('data/income_zipcode.csv', encoding='latin1'))
    next(reader, None)
    for row in reader:
        row = [item.lower() for item in row]
        # col 0 = zip_code, col 1 = state_x, col 2 = county_x, col 3 = combine, col 4 = income
        try:
            c.execute('''
                INSERT INTO income(zipcode, county,state, avg_income)VALUES(?,?,?,?)
            ''',(row[0],row[2],row[1],row[4]))
        except sqlite3.Error as e:
            print("income, insert error:", e.args[0])
    conn.commit()
    
    
    
    
    
     # user table : col 0 = average_stars, col 1 = review_count, col 2 = user_id, col 3 = yelping_since   
    reader = csv.reader(open('data/user_data.csv', encoding='latin1'))
    next(reader, None)
    for row in reader:
        row = [item.lower() for item in row]
        try:
            c.execute('''
                INSERT INTO users(user_id, review_count, yelping_since, average_stars)VALUES(?,?,?,?)
                ''', (row[2], row[1], row[3], row[0]))
        except sqlite3.Error as e:
            print("users, insert error:", e.args[0])
    conn.commit()
                      
                      
                                         
                      
    # review fact table
    # 0 business_id
    # 1 date
    # 2 review_id
    # 3 stars
    # 4 text
    # 5 user_id
    
    # col 0 = business_id, col 1 = date, col 2 = review_id, col 3  = stars
    # col 4 = text, col 5 = user_id
    reader2 = csv.reader(open('data/review_subset.csv', encoding='latin1'))
    next(reader2, None)
    for row in reader2:
        row = [item.lower() for item in row]   
            # review table    
        try:
            c.execute('''
                INSERT INTO review_fact_table (review_id, 
                                                user_id, 
                                                business_id,
                                                zipcode,
                                                review, 
                                                r_stars, 
                                                r_date)
                SELECT ?, ?, business.b_id, income.zipcode, ?,?,?
                FROM income, business
                WHERE income.zipcode = business.postal_code AND business.b_id = ? 
                ''', (row[2], row[5], row[4], row[3], row[1], row[0]))
            
        except sqlite3.Error as e:
            print("review_fact_table2, insert error:", e.args[0])
    conn.commit()

# %%
# create_database(conn)
populate_database(conn)

# %%
# for t in['business', 'income','users','review_fact_table']:
#     print('%s:'%t)
#     print(pandas.read_sql_query("SELECT * FROM %s"%t, conn), '\n')

# %% [markdown]
# # Initiate database & SQL

# %%
# !pip install ipython-sql
# %reload_ext sql
# %sql sqlite:///yelp.db
# Out:
# Requirement already satisfied: ipython-sql in /Users/zhangtong/anaconda/lib/python3.6/site-packages
# Requirement already satisfied: ipython-genutils>=0.1.0 in /Users/zhangtong/anaconda/lib/python3.6/site-packages (from ipython-sql)
# Requirement already satisfied: ipython>=1.0 in /Users/zhangtong/anaconda/lib/python3.6/site-packages (from ipython-sql)
# Requirement already satisfied: prettytable in /Users/zhangtong/anaconda/lib/python3.6/site-packages (from ipython-sql)
# Requirement already satisfied: sqlparse in /Users/zhangtong/anaconda/lib/python3.6/site-packages (from ipython-sql)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /Users/zhangtong/anaconda/lib/python3.6/site-packages (from ipython-sql)
# Requirement already satisfied: six in /Users/zhangtong/anaconda/lib/python3.6/site-packages (from ipython-sql)
# 'Connected: None@yelp.db'

# %%
# %%sql

# %%
# %%sql
# UPDATE review_fact_table 
# SET income_id = 
# (SELECT income.id 
# FROM income, (SELECT business.b_id, states.state, states.county FROM states, business
# WHERE business.postal_code=states.zipcode) as z
# WHERE income.county = z.county AND income.state = z.state);

# %%
# %%sql
# SELECT business.b_id, states.state, states.county FROM states, business
# WHERE business.postal_code=states.zipcode

# %%
# %%sql
# SELECT * FROM review_fact_table LIMIT 1000
# Out:
# Done.
# [('byrzj8rf2kjwlr-cunu6ea', 'kzyloqijvyw_fwftw2rjiq', 'jqsnfozdpxpmourswcg1vq', 85374, 'this place is horrible, we were so excited to try it since i got a gift card for my birthday. we went in an ordered are whole meal and they did not except are gift card, because their system was down. unacceptable, this would have been so helpful if we would have known this prior!!', 1.0, '2017-06-03'),
#  ('kznhtw1qido_9gx6sdqpjw', 'vgzqqqe8cj6sbmh0eqdliw', 'jqsnfozdpxpmourswcg1vq', 85374, "this review is based upon consistency of flavor and great customer service.  we came and there was an unknown issue that required a 25 minute wait fo ... (690 characters truncated) ... rant culture.  kudos to the manager for creating this culture.  ordered- fried rive and tofu, edamame, won ton soup, dynamite chx, and thai curry chx", 5.0, '2017-03-12'),
#  ('hwrtvn3lc-rwn6udv4wjzq', 'o7g_c6wfxsygr82qs0gaca', 'jqsnfozdpxpmourswcg1vq', 85374, "i love this place i'd recommend it to anyone ! we always order it togo and it never disappoints! the food always taste fresh and is always ready on time! definitely our favorite lunch spot !", 5.0, '2016-12-19'),
#  ('gieb_a-m9hux521wqnbl8w', 'ug4eku13jrwzrix6esindg', 'jqsnfozdpxpmourswcg1vq', 85374, '1st! place is not closed. there was an issue with legal workers in the franchise chain. now they are back! food is one of the best! especially their  ... (76 characters truncated) ... ! her favorite is their mongolian beef, and noodles! they are always coming up with something new, so you may have to try them more then a few times.', 4.0, '2011-08-10'),
#  ('gki4i6qocigaycwv1_0zzq', 'zzg6yr27liy3xwuyvgho7w', 'jqsnfozdpxpmourswcg1vq', 85374, 'definitely not a fan. coming from orange county, ca, i have high expectations when it comes to asian food.  suffice to say that panda express would have been a better choice, which is pretty sad.', 2.0, '2013-06-17'),
#  ('orhwg2mmcznwfkfjhkvuha', '1yorww0z-yduyc5gplnabw', 'jqsnfozdpxpmourswcg1vq', 85374, "pretty good, not great. definitely overpriced. it's barely a step up from panda and not worth the price difference. not saying it was bad, but $25 for two basic dishes is a bit much and they didn't make the order how i requested.", 3.0, '2015-11-03'),
#  ('qxwku_ob3fcj9vczfuzwwg', 'ujopjez_kxzayzdnji-2ng', 'jqsnfozdpxpmourswcg1vq', 85374, 'i wish i could give 1.5 stars. nothing special. lack of flavor. the entrees were either sweet or spicy. the crab rangoon were.....different. the filling had a mealy consistency. friend rice was bland. plenty of other places to spend 50$ on takeout. save your money.', 1.0, '2017-07-08'),
#  ('5ntaw5ewxk595kp4ynnisg', '6aeun50d3ts7migu6wdpka', 'jqsnfozdpxpmourswcg1vq', 85374, "disappointed that on yelp their hours show them open at 1030am but when you arrive they don't open until 11am. waiting in the car to pick up a large order makes me think twice about catering from here. don't get me wrong the food is great as always but they need to fix this.", 2.0, '2015-09-22'),
#  ('ai6o4uqqdqnjo7gfz6jbka', 'r6vb0ftmclhfwajs_auusq', 'jqsnfozdpxpmourswcg1vq', 85374, '1st visit had the lo mein...delish!  \n2nd visit had the teriyaki...fine if you like salt.  ick!', 3.0, '2012-10-08'),
#  ('zrvsd7psypolii3gp4-uhw', 'cpuuagt2rfujm6hrgxn3jq', 'jqsnfozdpxpmourswcg1vq', 85374, "as a vegetarian, it can difficult to find places with good options, but i love getting a tofu bowl at pei wei. the first time i had it, i had to double check because it looks and has a similar texture to meat, but it's great. i love going to pei wei", 5.0, '2015-12-28'),
#  ('p7oqbxtjwmin_xyohb6tfw', 'oyrbjbwy1uom12n3coks_q', 'jqsnfozdpxpmourswcg1vq', 85374, 'typical big business chinese place. slightly fancy but very average food. kinda like a fast food place.... you walk up and order then get your own dr ... (114 characters truncated) ... s but it all tastes pretty bad\n\ndo yourself a favor and also support a local business and eat at big buddha around the corner. its much better food', 2.0, '2009-11-18'),
#  ('ukpjwnetf5wghgrsxmprwa', 'pkzlwaggbtqcjjtghypeta', 'jqsnfozdpxpmourswcg1vq', 85374, "i love pei wei since it's just a bit more affordable than pf changs.\n\nthis is the first restaurant in the chain where i found patrons tipping the s ... (22 characters truncated) ... 't mind leaving a dollar when it's due i find it hard to do when they don't do very much, especially since it's more of a counter service experience.", 4.0, '2012-07-29'),
#  ('mt6u5lujk_ziciqux92sea', '9bj6j0zrv1xsisnzqwm5tw', 'jqsnfozdpxpmourswcg1vq', 85374, "great fresh food and clean restaurant. friendly and very accommodating staff. i'm a frequent visitor. this is a sister restaurant to pf chang's, but  ... (34 characters truncated) ... ices. great place to eat if you want the same style foods as pf chang's, but a more laid back environment without the need to dress up or spend more.", 4.0, '2016-06-19'),
#  ('yxaxextdwtdmheb14rgfrg', '8ncmv4rmwf4gpan-a_2tfw', 'jqsnfozdpxpmourswcg1vq', 85374, "this is pretty good. my wife and i usually split lettuce wraps and an entree of some sort. it's convenient to be able to order take out online. overa ... (53 characters truncated) ... ing to make the drive a little further out to big buddha on greenway and the 303, but this is a good substitute as it's about 1 minute from my house.", 3.0, '2012-08-23'),
#  ('ue6ts-ga9khywe76lel1kg', 'tbaqmmvlhxvxhe6kifrz-a', 'jqsnfozdpxpmourswcg1vq', 85374, 'food is good and consistent and the service is always great. i\'ve never dined in, but get take-out fairly often. i love being able to just say "same ... (177 characters truncated) ...  everything, but they are fine with custom orders if you don\'t want them. all in all, it\'s not my favorite place, but i always enjoy it every time.', 4.0, '2009-06-25'),
#  ('wstyqsynyud7xpwfrgwi0g', '1s0q1kwgpjikvd-srspwjw', 'jqsnfozdpxpmourswcg1vq', 85374, 'the hubs and i dined at the glendale location about two years ago. i guess we were hoping it was like pf chang\'s....but unfortunately were dissapoin ... (1072 characters truncated) ... ...they offer take out too so you can enjoy great food in the comfort of your home....without all the noise! (or they have a patio you can dine from)', 4.0, '2008-10-06'),
#  ('g9yv-m3kvoqfpyjhcjurdg', '-0kidututovyfqn_neqmsw', 'jqsnfozdpxpmourswcg1vq', 85374, 'very clean and staff is always friendly. i usually order the honey seared chicken but decided to switch it up. i ordered the thai dynamite and it had a weird, almost chemical taste. i will go back but will stick to my usual order.', 3.0, '2015-03-17'),
#  ('fk8oi26dahqfot46t_sxwg', 'krq_dwobn2voaqlnv7hj8a', 'jqsnfozdpxpmourswcg1vq', 85374, 'if i could give no stars i would. my family placed an order to be picked up and were told to be there at 7:20. we get there and i sit waiting for the ... (389 characters truncated) ...  loves fried rice and wouldn\'t even eat hers, it was so greasy. we all ended up eating pb&j\'s and it was 100x better than anything we brought home.', 1.0, '2014-04-22'),
#  ('j51qebi4hmm6whglkt57xg', 'uxzdrvdx8ejqdqb13bcfcg', 'jqsnfozdpxpmourswcg1vq', 85374, "haven't eaten at this location in particular, but in general the prices are high for what you get.  it's nothing special and any other chinese place in the city can probably beat it in the price/quality area.", 2.0, '2009-01-24'),
#  ('fkcizccgm5lrdh0fxnoplg', 'ektcccgwn9maidnssdwuig', 'jqsnfozdpxpmourswcg1vq', 85374, 'always on point. i get the carmel chicken.. the crab wontons are a guilt must have. and i love there  tea too. ate her for two years and always pleased. thx!', 4.0, '2014-08-28'),
#  ('tgg8n3cb3klppdamj88owa', 'rhp3q9ok1qu9_tjmiy4i9w', 'jqsnfozdpxpmourswcg1vq', 85374, 'i love pei wei. the food is delicious. the atmosphere is chill. the restaurant was clean and staff friendly.', 5.0, '2015-11-01'),
#  ('hqcbuqxmvb2quq2mvv3apg', 'bweluovj3cijmp2qp4vjeq', 'jqsnfozdpxpmourswcg1vq', 85374, "came here with my friend today cause we were starving and decide to go whichever next place we saw. and we were very surprised at how pretty the insi ... (473 characters truncated) ... very nice! and this place is vivid and just amazing. way better than panda express. i will definately come here again, and recomend it to everyone!!!", 5.0, '2010-01-10'),
#  ('p8h9lk3qwwzaygm4ueceqa', 'c38sl6ti_dvrpl5sg4kmfw', 'jqsnfozdpxpmourswcg1vq', 85374, "very consistent food. definitely a second best to p.f. chang's.", 5.0, '2010-07-04'),
#  ('lp1odcha7dmvpblhb4dgmg', 'cs6bipoag9smtvb44hu9sw', 'jqsnfozdpxpmourswcg1vq', 85374, "service is fast and on time. love the online ordering-very convenient!  food is always hot and delicious. however...no forks for take out?  that is p ... (17 characters truncated) ... ither you didn't order in time or there was a problem with the order...either way, hustle your booty to walmart and buy a couple boxes: unacceptable!", 3.0, '2015-10-29'),
#  ('_lap3daoe--w6jmcg4hfjg', '1fmdrdfb3ihpcka9seshsa', 'jqsnfozdpxpmourswcg1vq', 85374, 'the food was fantastic! i highly recommend  the lettuce wraps.', 4.0, '2013-06-21'),
#  ('rmuw5m75o_5rgl2mtmfg2g', 'zlt0qu_98zgobybtcg7jrq', 'jqsnfozdpxpmourswcg1vq', 85374, "then we went to dinner at pei wei. not bad for an asian fusion place. filled with senior citizens, but that's not all that surprising. i had the mang ... (168 characters truncated) ... appetizing. not crazy about the moderate wait nor the fact that strangers came up to the table with unnecessary parenting advice for steve and chris.", 4.0, '2010-07-02'),
#  ('9-mx4vabytmxjdrlfnzzba', '33h6cgtb9msyhi0-kbxmhw', 'jqsnfozdpxpmourswcg1vq', 85374, 'we use them to cater family get-togethers. love the vegetarian dishes, especially the baked tofu- yum!  the mongolian beef is a favorite with family.  when we dine in we always get the lettuce wrap.', 4.0, '2012-09-11'),
#  ('fxaxyxj5sbiotck36bjxca', 'mce5judzp-ihu_6cwqsiiw', 'jqsnfozdpxpmourswcg1vq', 85374, "we went as a family of 6 and was treated very poorly by the manager at the  place. the food was greasy (i guess most americans would love it since th ... (308 characters truncated) ... ing fancy is not the attraction motto for me. maybe they will train their managers to change the attire of the restaurant. i wont waste my time here.", 1.0, '2011-02-27'),
#  ('wmoivnocytzfnsjab-5ria', 'daipugisy71nox0wnuc27w', 'jqsnfozdpxpmourswcg1vq', 85374, 'pei wei has become a favorite "take out" spot for both myself and my girl friend.  we drive a little further than the local taco bell - kfc combinati ... (355 characters truncated) ... cken with brown rice.)  \n\nif you haven\'t give pei wei a try, stop in some time. i believe you\'ll enjoy it -- that is, if, you enjoy asian dishes.', 5.0, '2016-03-17'),
#  ('zuko5ty7zxqzf8-uu0r8rw', 't9lwepmlz7sl_wiw9sfsrq', 'jqsnfozdpxpmourswcg1vq', 85374, "it's just above average.  portions are decent and cost was ok.  got in and out fast by phoning our order in.  good was ok, it didn't floor me but it didn't make me not want to there again.", 4.0, '2015-08-08'),
#  ('l8cggc6aahcj8xomkyrzaw', 'p_azadim_uwfoxahhkb3ag', 'jqsnfozdpxpmourswcg1vq', 85374, 'in surprise this is probably the best chinese offering which isnt saying a whole lot. i really wish there was an awesome offering out there in terms  ... (485 characters truncated) ... urprise having so many chains it wasnt surprising to see one of these finally opening up.. a far better choice than panda express.. kind of sad, huh?', 2.0, '2008-11-27'),
#  ('kaa5n5ie00ofi0w0k53wsa', 'gg9taoec9sma_dokskkima', 'jqsnfozdpxpmourswcg1vq', 85374, 'pei wei is the fast food version of pf changs. there\'s a long and interesting story surrounding pei wei and that of pf changs. let me just say that, ... (674 characters truncated) ... e rice is almost always dry and is cooked incorrectly in massive amounts, as well as being a long grain, not short grain rice. not worth the money!!!', 3.0, '2017-06-10'),
#  ('k53lj6hucbpbqzwynfobsg', 'cpfnf9pavvjamedzm3wtza', 'jqsnfozdpxpmourswcg1vq', 85374, 'i love the lettuce wraps here. they are simply the best.  i order carry out often from here. i occasionally dine in.  my problem with the dinning in  ... (107 characters truncated) ... rty of more than 4 most days you can hang it up.  other than the seating i like it. large portions of rice and noodles.  a little stingy on the meat.', 4.0, '2013-04-26'),
#  ('uljhnka4iikk9fvyvfphqa', 'mfkjhdwguk0kdzntef07_a', 'jqsnfozdpxpmourswcg1vq', 85374, 'just dirty ... sometimes i wonder why we come back here. at the register the girl handed me a cup. there was particles of food on the inside. i hande ... (79 characters truncated) ...  cup back with the other \'clean\' cups. i stopped and restated "no. it\'s dirty, you probably shouldn\'t give it to someone else." (shaking my head)', 2.0, '2014-12-27'),
#  ('en6k7nf2sqxjc3nkljx0cw', 'e3s63222bmnliyli2dceqg', 'jqsnfozdpxpmourswcg1vq', 85374, 'hot,vegan,carbo load \nyou name it and they have it\npricing is reasonable  and quality excellent \nno disappointments here\nfive stars for the food \nwe try to stop by monthly', 5.0, '2017-04-23'),
#  ('uiss0hd9l4krcvwx0jmugg', 'gjxm-lmqcta13_diunivgg', 'jqsnfozdpxpmourswcg1vq', 85374, "i eat regularly (3-5 times a month) at pei wei, usually in scottsdale or north phoenix. my wife's doctor is across the street from this pei wei, so w ... (108 characters truncated) ... ten at. it is consistent, they don't get frustrated if you customize your order, and the cooks on always on point. \n\nwish this location was closer!", 5.0, '2016-03-02'),
#  ('nsuhkkb3vidwd0x7egzbuq', 'cnszfgho_ofsda3dog0cia', 'jqsnfozdpxpmourswcg1vq', 85374, "love the food but it's great at all locations. the customer service is horrible at this location. only two tables were occupied at the time we walked ... (232 characters truncated) ... sting his time.  no thank you, nothing. just a hand to take my money and then a bag in my face so i would leave and get out of their faces. really???", 1.0, '2014-10-27'),
#  ('m6qzu16sjxoyolrmnenhqg', 'kq0emtske2dcdowbe1nyrg', 'jqsnfozdpxpmourswcg1vq', 85374, 'we are from the midwest and are visiting phoenix on a vacation. we stopped in this place for some quick asian food. what a great surprise! i had the  ... (3 characters truncated) ... golian chicken and it was great. very similar to pf chang. you order at the counter and they bring the food. i wish we had one of these where i live.', 5.0, '2017-03-06'),
#  ('wjcm9kzfqp3d2r6uqblzzg', 'migfb8yh-zsooh0u2y8msq', 'jqsnfozdpxpmourswcg1vq', 85374, "i usually go to pei wei regularly and am usually over all satisfied.  however today did not go well . first i was unable to order online,   when i  w ... (722 characters truncated) ... mber on my gift card and they assured me that i did have a credit balance which leave's me wondering what are gift card's good for? \nbuyer beware...", 1.0, '2017-01-24'),
#  ('4rf8dmnbw-p2etlupme_4g', 'rv6_u_4asoq-l50anrunng', 'dwqezbfen2gdihllfweexa', 44060, 'enjoyed the bright fun mexican decor!  the food was delicious and reasonably priced!  and the margaritas were delicious!', 4.0, '2011-08-21'),
#  ('clgrkj6dqim7vskjbj2w6q', 't5mgs0nhbcwgofz6q6btng', 'dwqezbfen2gdihllfweexa', 44060, "i've been here at least 5 times now and each time is better than the last. i iove what they have done to improve the building and add outdoor dining. ... (36 characters truncated) ... par with other top places in mentor. i really suggest the chicken soup on a cold day it's very yummy! everything i've had on the menu has been great.", 4.0, '2013-06-03'),
#  ('ibctqmvwvd5zqqhuvfdnxg', 'ntkmugqcis30gjakq91eta', 'dwqezbfen2gdihllfweexa', 44060, 'terrific service. the place was packed, but we were seated right away. chips and salsa on the table as we were seated. great food, big portions, fast service.', 5.0, '2014-03-15'),
#  ('69kni-xg6qtg9y3hq_zw5g', 'uney79t6hhecp9yd58r1dg', 'dwqezbfen2gdihllfweexa', 44060, 'ate here for lunch on a sunday.  arrived around 12:30, and there were a decent number of customers seated.\n\nservice was friendly and fast, food was excellent, and they have draft beer, including a couple of mexican brews.\n\nthis location is the best don tequila i have been to.', 4.0, '2014-06-09'),
#  ('rqoasxlfcdnwlnw27vhnya', 'uwfgmooul1fc79ici5h2mq', 'dwqezbfen2gdihllfweexa', 44060, "been dining here since it first opened. wife is from tx so this is her taste of home. when tx folks come to visit they ask to go to don's. \nit's very good tex-mex.", 5.0, '2012-02-25'),
#  ('egtrhsii_ungvelsxjynsa', 'kqsbidrm1u34q0rqn62qia', 'dwqezbfen2gdihllfweexa', 44060, 'if you have a hankering for mexican, head on over to don tequilas. fast service and delicious food with generous portions. we ordered the guadalajara special tamale and the pollo adobe and they were both delicious.', 5.0, '2014-03-15'),
#  ('o5ufgcbj4osaeeolc_muua', 'bygay3hu2s5geij5wmud0w', 'dwqezbfen2gdihllfweexa', 44060, "kind of disappointed with the previous reviews in the area of customer service because honestly there was none. we were the only patrons in the resta ... (507 characters truncated) ... expensive. if you order a quesadilla you may want to order a la carte items as well because the quesadilla was the size of a large taco which is odd.", 3.0, '2011-06-14'),
#  ('dq7ir4uvsvwpfqkqaltmtw', 'iizhrdyomcygdiwswaldmw', 'dwqezbfen2gdihllfweexa', 44060, 'i eat here all the time and most of the staff are from guadalajara.... food is definately "americanized" and by that i mean tamed down in heat and ch ... (135 characters truncated) ... re big smiles and hot sauce.... so if your in the mood for authentic hotmexican food.... just let the waiter know.. hell guide you to a great choice!', 5.0, '2013-04-24'),
#  ('h4ecwtdoo_sjwelf62bjwq', 'tv0n0henyg4krjja7glzha', 'dwqezbfen2gdihllfweexa', 44060, "inconsistent service, average food.....i've had better at chipotle.....\n\nwon't be back.", 3.0, '2017-07-01'),
#  ('0iou6fa2x-rcvtxb8xvheg', 'rt1sd4kdpd6uquf9bisw2q', 'dwqezbfen2gdihllfweexa', 44060, 'always the same old bad mexican food. at least this time i did not get the nearly 2 foot piece of hair in my fajita burrito.\nwhy many people i know, including my wife like to go to this place is beyond me.', 1.0, '2012-12-10'),
#  ('ysv7ynllze9tv3gkzf0d3g', 'xu3fi_o1xrjgrzoifwvjbw', 'dwqezbfen2gdihllfweexa', 44060, 'very good, reasonable priced . the texas quesadilla with chicken, \nsteak, shrimp, onion, peppers and cheese was large and very good\nthey have dos equis on draft!', 4.0, '2015-09-07'),
#  ('cwigjrzxj0wofgma4ycdig', 'b7zwpm3mdi074pbsw9gsia', 'dwqezbfen2gdihllfweexa', 44060, 'what a surprise!  the most amazing mexican food i have ever tasted and i am a foodie. my husband and i ordered the table side guac.  delicious!   tex ... (79 characters truncated) ... ivating for them soon!  all of the food was so fresh!  you must try this place. we will try the green road location next as it is closer to our home.', 5.0, '2013-11-23'),
#  ('dmvajhino21faymc74yegq', 'vueijf36ja09bwzjukonpa', 'dwqezbfen2gdihllfweexa', 44060, 'amazingly good mexican food but they rip you off every time.  they scratch your order on a piece of paper with no descriptions and prices never add u ... (178 characters truncated) ... o bad they scam their customers like this because the food really is awesome.  write down everything you order and be prepared to question your bill.', 2.0, '2016-12-16'),
#  ('oj67tgc1zbwyzzzi-7dikq', 'nbezzsqfrohs9ol2v4nyua', 'dwqezbfen2gdihllfweexa', 44060, 'the service was ok, the salsa flavorful, and the food pretty good. they only serve pre mixed margaritas,  which is no bueno. i ordered the burrito fajita and it was great, but the kids nachos were bland and rubbery.', 3.0, '2017-06-04'),
#  ('ur_lsekj5wzjlo-tcwwmig', 'cifybnsdhrphw0lofmmeeq', 'dwqezbfen2gdihllfweexa', 44060, 'we came here for the first time to celebrate my birthday.  we ate a ton of fresh chips in advance of the meal, the salsa was pretty mild.\n\ni had th ... (140 characters truncated) ... uge portion home and ate it the next day.  \n\nthe service was seriously, amazingly fast for a group of 4, and they kept our drinks regularly filled.', 5.0, '2014-03-21'),
#  ('mvthe_xt5r-nxwm4btoxea', 'xlp2qzyxgbg31wfhsdhkww', 'dwqezbfen2gdihllfweexa', 44060, "with everywhere else packed on a friday night, we wondered in, not expecting much quite honestly. \n\nwe both ordered off the specials menu, and my h ... (341 characters truncated) ... r for a second meal tomorrow.\n\nprices were very reasonable - our total bill, including tips, was less than $25.  definitely planning another visit.", 4.0, '2010-03-20'),
#  ('szi_v454dd6hmxsi-wszpw', 'vkowrnwgphgpqev9zananw', 'dwqezbfen2gdihllfweexa', 44060, 'i don\'t understand all of the high marks for the this place. the chips were not good and the salsa wasn\'t good either.. the chips were bland, old a ... (393 characters truncated) ...  our meal. while el rodeo and el patron are nearby, and have far better food,i cant understand what the attraction is to this place, will not be back', 2.0, '2013-09-11'),
#  ('rwzyknl1ba54ascotgiqua', 'eyyzbulj8uii41drycctuw', 'dwqezbfen2gdihllfweexa', 44060, 'on a recent trip to kirtland, oh.\n\ndecided to try even though the outside appearance was somewhat questionable.\n\nbut nice simple decor inside.  friendly waitress who gave good tips from the menu.\n\nwe both had the tres amigos.  nice chicken, steak, shrimp combo.', 4.0, '2010-08-22'),
#  ('1jgdqwrj4irganfqioxf1q', 'kq-gi-xszzq5xehyev6eyg', 'dwqezbfen2gdihllfweexa', 44060, "if you blink. you will miss this little eatery, squished into the corner of a small strip mall in mentor, ohio.\n\ni went with a friend of mine from  ... (347 characters truncated) ...  and pleasant.  now that i know that this place exists, it gives me even more reason to travel to the northern tip of ohio for good company and eats!", 5.0, '2011-07-26'),
#  ('8sk2ci8cuozrxkp1hpkpnq', 'is6jbvbi3fbjfocd9cjwva', 'dwqezbfen2gdihllfweexa', 44060, 'good food, great prices, large portions, fast, friendly service. what more can you ask for. we highly recommend you try it!', 5.0, '2014-08-14'),
#  ('z6wg7rrconwjlxe8ajypeg', 'ybbnemmb8wwbkgr6v3bcaa', 'dwqezbfen2gdihllfweexa', 44060, "this will probably be my last review of this location. i was at don tequila yesterday & the cashier was talking  to me but i couldn't understand so i ... (377 characters truncated) ... s and sweaters in the summer because he is a pervert. \n\nit was very disrespectful and unprofessional and i feel uncomfortable eating there anymore.", 1.0, '2015-06-05'),
#  ('nsbc7jsjun3ru4vf3f21dg', 'clhrqrnrrpj7ht-oqsff7g', 'dwqezbfen2gdihllfweexa', 44060, "sometimes you need a little spice in your life. don tequilla delivers. the neon sign beckons you inside and once there, sit back and enjoy.\n\nthe ro ... (666 characters truncated) ... als, burritos with tomatillo sauce!!! \n\nthe staff is friendly and patiently gives you time to check-out the menu and answer any questions. nom.nom.", 3.0, '2014-04-04'),
#  ('wpgxlaqx0z7fvh1phinylg', 'mgbv4e-z6lfyucsvwpxqpa', 'dwqezbfen2gdihllfweexa', 44060, "i love this place!\n\nfirst impressions this place is a fun atmosphere filled with mexican clay rooftops and colorful furniture.  you get your chips  ... (658 characters truncated) ... self coming back to this fun filled, warm, family owned place and always leave feeling satisfied.  for taqueria style tacos, try the tacos el pastor!", 4.0, '2012-11-26'),
#  ('5oldxf5fjfwrcz20xdfdxg', '4pvwunpfwn8nwrskt0urva', 'dwqezbfen2gdihllfweexa', 44060, 'authentic. delicious chips and salsa follow you to the table on arrival - food arrives on plates too hot to touch. we lived in the south west for 9 y ... (74 characters truncated) ... ite. we have been enjoying perfect food here for 6 plus years. very little turn over in wait or kitchen staff... consistent quality food and service.', 5.0, '2016-01-01'),
#  ('baqyujh1oimnayobw_aqfw', '5z587ibrnjcbo51iahnpzq', 'dwqezbfen2gdihllfweexa', 44060, "why hello service. don't let the lime green walls scare you, this place is all business. seated immediately, the waiter came to the table immediately ... (353 characters truncated) ... it arrived it was covered in whipped cream and strawberry sauce which i am not a fan of. the consistency was nubbly. should've went with the churros.", 4.0, '2010-08-18'),
#  ('0yqwd0usyspapi7zuw4jaw', '-s1dz92q3rpfhomiqeep8q', 'dwqezbfen2gdihllfweexa', 44060, "passed this place a few times and finally decided to try it. i got the #17 on the lunch menu. it was a burrito  with eggs, chorizo and cheese.  it wa ... (534 characters truncated) ... mind waiting a few minutes for some really good food. overall the place was cute, people were friendly but food was less than ok. i wouldn't go back.", 1.0, '2011-10-28'),
#  ('pvpme6bwfk6w-1zvat94nq', 'ludx46lefeq8tuhsk0d9zw', 'dwqezbfen2gdihllfweexa', 44060, 'this is our go to mexican restaurant. the staff is kind and courteous and javier is an amazing gentleman. always prompt , fresh and delicious. their mango margaritas and dos equis pair perfectly with our meals. very family friendly and great atmosphere. really a great place', 5.0, '2016-04-02'),
#  ('d1y0paqpoq_ml-xil4pz6a', 'rk2agpweu7uvwz_fqke8ma', 'dwqezbfen2gdihllfweexa', 44060, "food was awesome. the normal tacos are ... well ... normal and typical. my wife ordered the chicken fajitas and they were very good fajitas. i ordere ... (119 characters truncated) ... nd it actually came with pretty good heat. the burrito was outstanding, which is why i gave it 4 stars instead of 3. overall, we'll probably be back.", 4.0, '2012-09-12'),
#  ('yed_rnjwbt03ua2tw56zfa', 'xeocjjwfllkpksd_oyxygq', 'dwqezbfen2gdihllfweexa', 44060, "food is always great especially tableside gauc but today service was really slow because of kitchen. waiter couldn't have been nicer", 4.0, '2017-06-02'),
#  ('m8g0a_w1achxrocyxg0paw', '3o2vt1qybhjpm_ycholxla', 'dwqezbfen2gdihllfweexa', 44060, 'we had a really good meal here, service was quick and accurate.  food was definitely better than most mexican places around.  margaritas were very good.  most of all, the place was very clean!  would definitely go again!', 5.0, '2016-09-17'),
#  ('3v3s0lyintbqen-lbh9vna', '09jpzrkd_j0sg9wpbdsjqg', 'dwqezbfen2gdihllfweexa', 44060, 'went on a saturday night on the first night of summer, and had a party of 12.   we were sat almost immediately.  went there because they had catered  ... (648 characters truncated) ... d came out fast, they did have the world cup and that seemed to distract the waiters...but as far as mexican food goes it was pretty good for mentor.', 4.0, '2014-06-25'),
#  ('bbkephdzhni_vzvtkfv-oa', 'nvi6nkdkut_x5gommcngdw', 'dwqezbfen2gdihllfweexa', 44060, 'your basic traditional mexican style restaurant, never at in only ordered out.\nmade me wait for a hand full of my orders when i came to pick it up..but super tasty. with a lot of hit and miss items in the menu.', 3.0, '2016-09-09'),
#  ('z8p9ek2sogynyg9jqh25tw', 'gf_vd1mjrnoqldljdwidnw', 'dwqezbfen2gdihllfweexa', 44060, 'very bland. salsa is like tomato sauce. enchilada sauce taste like canned marinara.. just awful.', 1.0, '2017-01-14'),
#  ('mjkzoje7wi5v7sjahgcj-q', '2rihr_3qznlhn73yfowkwa', 'dwqezbfen2gdihllfweexa', 44060, "been here a couple times and so far every time we've gone the foods been great, the service has always been friendly and the portions are amazing!", 5.0, '2015-01-28'),
#  ('2pfpmmcxr3kedhlo7k_n-g', 'o82jtasa6rsgkl2jqikfpa', 'dwqezbfen2gdihllfweexa', 44060, 'tacos al pastor--delish! salsa and guacamole was very fresh! refried beans were super good. service was friendly and fast. beer was cold and the bathroom was clean. what more can you ask for?', 5.0, '2016-06-04'),
#  ('v-yiu3dc3prlkoh1byouaw', 'xxvz5g67eacr3emnky5m6w', 'dwqezbfen2gdihllfweexa', 44060, "so, i thought the food was average. but what makes this place is the cool interior and super attentive and friendly bartenders and servers.  we felt  ... (138 characters truncated) ...   my bean burrito and cheese enchilada were standard fare. nothing to shout about. the beer was extra cold so bueno for that.  very clean restaurant.", 3.0, '2017-07-04'),
#  ('nlirntabmkq5-vu2jsjqkg', 'tqtmic2hzxjxmemls5l0-g', 'dwqezbfen2gdihllfweexa', 44060, "we've been going here several times a month ever since they opened. some of the best mexican food i've ever had at absolutely the lowest prices i have ever found for food this good. waiters friendly and attentive. nice decor. nice new bar.", 5.0, '2012-12-02'),
#  ('abeny93amsym7hn8uxprrq', '3kkt6smpflgvbs1pndbr8g', 'mkd_eud0pg__cofibeqyag', 15217, "my go to place to study!  they play great music at a volume where you can still hear yourself think.  it's almost never crowded, and the people that  ... (427 characters truncated) ... at it's small, and there aren't a lot of places to sit.  if you are the mood to try a variety of tea, or just need a place to study/relax this is it!", 5.0, '2011-12-20'),
#  ('kigrd0zhudf1k1xlc0jjga', 'tsbuwbhrhuiemxb56kl0cg', 'mkd_eud0pg__cofibeqyag', 15217, "this place is ridiculously cute, colorful, and cozy, with a huge selection of loose leaf teas.  they offer teas by the pot only, except for iced teas ... (1181 characters truncated) ... pers and reading materials are usually available to pick up, and there are board games in the back.  this is a great place for a rainy (or cold) day!", 4.0, '2012-11-01'),
#  ('ngv40rxmrl_in6lwpyrsma', 'um2iec4nkmxvpjeme3pfkg', 'mkd_eud0pg__cofibeqyag', 15217, "you can purchase from a huge variety of loose leaf teas. it's one of the few places i know that really pays attention to brew times and water tempera ... (186 characters truncated) ...  lots of plug in places for your laptop. the benches aren't terribly comfortable, but the couches are. plus, the people behind the counter are great!", 4.0, '2008-01-17'),
#  ('8fvvpvtamjam5drd18jxaa', '135dbbqnr3bekqbbzz9t1a', 'mkd_eud0pg__cofibeqyag', 15217, "i dropped by te cafe a week ago with cm to check out their offerings. as a tea lover, having passed it many times on murray, i'd long been curious ab ... (1777 characters truncated) ... e for a change of pace. i'd definitely return for another visit in the future to sample more interesting teas--and to play another round of dominoes!", 4.0, '2015-02-10'),
#  ('cbamcmdnj6fcu5jbkrfgfw', '3ew6beek14k6x6omt5gbig', 'mkd_eud0pg__cofibeqyag', 15217, "came on a weekday afternoon to study and it was a good environment to do so. i got salmon sushi for a great price, and the pots of tea with free refi ... (35 characters truncated) ... yees are friendly and attentive. this place seemed like a nice casual place to spend a few hours studying, and i'd definitely recommend it to others.", 4.0, '2017-05-01'),
#  ('9bdozr1hs6atyknqprruyg', 'scnvdfmxtq4o2dbjphlbaw', 'mkd_eud0pg__cofibeqyag', 15217, 'amazing people \nloveeee the owners. best sushi in town best service and nothing beats their prices \ngood for bubble tea lovers', 5.0, '2017-06-22'),
#  ('fuesgmmv_tsmkervhqxxjg', 'g0eqgdevfl4dmn6jfarjfg', 'mkd_eud0pg__cofibeqyag', 15217, "this place hasn't changed a bit. still awesome tea, great service and friendly faces. although, the owners have changed, te cafe remains the same. \n\nso good to be back and sipping on my favorite iced lavender lemonade.", 5.0, '2011-07-11'),
# ...
#  ('dlbrjlevwxj05oxztnusng', 'hxj6lwogcd0jiphqo_ujkg', 'dkdapyvfdsnysnoso6nyla', 89109, "my boyfriend and i stopped in for lunch today. we wanted to see what all the fuss was about. neither one of us was impressed. i had to choke, literal ... (244 characters truncated) ... teak and lobster for that price in town and not be sick or disappointed. we can say we've  scratched it off of our bucket list, but will not be back.", 1.0, '2015-09-14'),
#  ('1nj8889bqucpv5phuayuqq', '9qjr5cmelqnrftmjohtdww', 'dkdapyvfdsnysnoso6nyla', 89109, 'these burgers are (in a musical tone) teerribbllle!\nwow i thought in and out burgers were bad, i could not even finish my food here. i took it out to the bums outside and even they wernt real happy about the offer.  this food really sucks.... wtf..', 1.0, '2015-12-27'),
#  ('vtw8x2_eeizg1hogx1u2og', 'ls50mezvpy2q90kpr0rbqa', 'dkdapyvfdsnysnoso6nyla', 89109, "white castle of the east on the vegas of the west!\n\ni've been to a white castle before in the bronx of nyc wile on tour being that is the only othe ... (1012 characters truncated) ...  you have never visited a white castle and your next to one after you've had a few drinks pay them a visit because you might like it more than i did.", 2.0, '2015-05-25'),
#  ('0fm6bia_zsma-sar_kltpa', '7bloigm84jqfe28skbxtfa', 'dkdapyvfdsnysnoso6nyla', 89109, "i'm confused. why would you choose this place over all other places in vegas? it's terrible. i had to try it because of the movie and i'm from the we ... (20 characters truncated) ...  my chance but it was a lesson learned. never coming back. flavorless. worst fries ever. mystery meat? why is the line so long? welcome to stinktown.", 1.0, '2016-02-10'),
#  ('kd76gkfdxf3-oerphbufug', '_yrb75iedp-m2xcwvgfm5q', 'dkdapyvfdsnysnoso6nyla', 89109, 'fries were good, but the burgers were just any old burger slapped together but just made mini.', 3.0, '2016-02-18'),
#  ('86nyiulyixfgatw8widwbg', 'qc-qjahct5sh3w7zh0ej5g', 'dkdapyvfdsnysnoso6nyla', 89109, 'oh how i love these little sliders. these sliders take me back to my youth and they are amazing. it is las veags, and it is a bit pricey,  but for an ... (230 characters truncated) ... rst had one as a little kid. if you did not grow up on these sliders than you missed out. i love white castle. finally the west coast is catching up.', 5.0, '2015-07-10'),
#  ('lvegicfju29om_9d40mq8a', 'swm1tw_7mrpk6ujnta4snw', 'dkdapyvfdsnysnoso6nyla', 89109, "for over 30 years i've been hearing about white castle sliders from those that lived in, or traveled to parts of the country that offered them. then, ... (1879 characters truncated) ... se was just okay. service was decent, drink fountain was nothing special. over all, 4 stars for white castle, mostly because of their famous sliders.", 4.0, '2017-03-15'),
#  ('wcljx7melkn4inewcn9sqa', 'bcar4psrsvac_ev7flulyg', 'dkdapyvfdsnysnoso6nyla', 89109, "what's all the hype???? i will never understand. \n\nupon arrival to vegas, two of my friends were so excited about this place, so we ended up going  ... (710 characters truncated) ... ic coming thru your restaurant, one would think you would have a clean up staff on duty at all times. \n\ni wasn't impressed, once was enough for me.", 2.0, '2015-06-24'),
#  ('hxafetdcxggueflqwoupha', '_uzcvkx9k9ujq93sivfdvw', 'dkdapyvfdsnysnoso6nyla', 89109, "this probably deserves a 4-star rating given most people's expectations, so let me clarify before i get into the review: i have no real qualms about  ... (4339 characters truncated) ... tites might be satisfied with 2-4 sliders.\n\ndon't forget to try out their other stuff, like jalapeno cheese, onion rings, etc. it's all good stuff.", 3.0, '2016-04-01'),
#  ('qsaukdc8-suedbunhgbsrq', '717xljhppbyljsjfrqw3rw', 'dkdapyvfdsnysnoso6nyla', 89109, 'i felt like i had to try it since it\'s so well known, talked about, and movie about it. i never make it to the east coast and now that there is one  ... (646 characters truncated) ... here is way better food on the strip, especially for burgers, but if you go here, i suggest just trying it for a drunking snack, not for a real meal.', 3.0, '2015-04-03'),
#  ('fsal6qdu_jj2elai-briqa', 'rykof3qsfd39fyloavn7og', 'dkdapyvfdsnysnoso6nyla', 89109, "so when i heard this famous east coast fast food burger joint was coming to vegas, i was really hyped! but when we got there it was met with disappoi ... (395 characters truncated) ... we went in on a wednesday around 11am). we found it easiest to get there by parking at the venetian and walking towards the strip and hanging a left.", 3.0, '2015-03-23'),
#  ('9f2e3ckkqdnzjyxn_n2oya', 'r5ggpc6occlk6ddl5yqsjq', 'dkdapyvfdsnysnoso6nyla', 89109, "even with people ordering craver crates of 100+ white castle sliders in front of me, my order came out fully cooked in less than 15 minutes. that's a ... (308 characters truncated) ... odated all of the people on opening day, so they should be good to go from now on. i like their fudge covered cheesecake bite on a stick for dessert.", 5.0, '2015-01-27'),
#  ('zo92xricdiaaswq2nhvqhq', 'znykbotzzm6o3x_x_thdrw', 'dkdapyvfdsnysnoso6nyla', 89109, 'i was not expecting a lot from white castle, as they do not advertise any gluten -free options. i was overly impressed. the manager at the location t ... (297 characters truncated) ... the flavor of the food made up for the price. i would definitely recommend going here if you are looking for a quick and delicious night night snack!', 4.0, '2015-06-04'),
#  ('0oocchlp--z6v2eeuwei2w', 'lm8tsbboy2andsmwvnzhnw', 'dkdapyvfdsnysnoso6nyla', 89109, "most people that eat here know what white castle belly bombers are. or the very similar crystal burgers. they aren't  gourmet burgers by any means, b ... (2 characters truncated) ...  these little squares are addicting! like little sliders that everyone should try. and this is probably the only one, anywhere, that serves beer too!", 4.0, '2016-07-16'),
#  ('misrpxh_zofdei_tbqphpq', 'luljzkrhp77ynllld6rulq', 'dkdapyvfdsnysnoso6nyla', 89109, "line moves fast here so even if long line it's so worth it.  white castle is the best, as long as you just expect a regular burger at a great price.  ... (233 characters truncated) ...  and you'll walk out full without your wallet hurt.  i'd compare it to in and out,  it's not 5 star burger,  but the price makes it uber yummy!!!  :)", 5.0, '2016-01-03'),
#  ('627ibnzl4-l-xm5nwj_fba', 'jpn-ldc7wctdwi9kp5ivsa', 'dkdapyvfdsnysnoso6nyla', 89109, 'my boyfriend and i were looking for a place to eat while driving down the strip & our taxi guy recommended white castle, he said its "cheap and delic ... (214 characters truncated) ... pointed. i also got a side of the onion chips and i was so grossed out when i bit into it and there was an onion peel inside instead of actual onion.', 1.0, '2016-03-17'),
#  ('nwldtedsq9gjddkwh7zj4w', 'yowbksh8tujr8cyvemq7sq', 'dkdapyvfdsnysnoso6nyla', 89109, 'finally got to eat at white castle in vegas!  i believe this is the only one near the west coast!  it was delicious and i tried almost everything on the menu!!!', 5.0, '2017-07-11'),
#  ('q-tnrqr95iscwrsr9fdnhg', 'wpk0vjt5dbh08wgoesrisw', 'dkdapyvfdsnysnoso6nyla', 89109, "so i'm from texas and was in town. i've always wanted to try white castle so i thought why not? \n\ngot there early around 10:30. no line and for my  ... (73 characters truncated) ... cheese wasn't even melted. fries were old and horrible. wish i could say better things, but for the price you really are better going somewhere else!", 1.0, '2015-03-02'),
#  ('jd8bf4y8oirhxojrz4reqq', 'mnrlasr0hn9f2wvtvrxsjq', 'dkdapyvfdsnysnoso6nyla', 89109, 'this is a great place if you want to pay for overpriced burgers which taste exactly the same as the frozen ones that you can buy at the grocery store. save your money and go to bachi burger or a few hundred miles to the closest in-n-out.', 2.0, '2015-03-17'),
#  ('ej-5byesgi1c1dl8vx0qtq', 'm4nzhqmjtglusmpzqmnbmq', 'dkdapyvfdsnysnoso6nyla', 89109, "so many haters...so little time. white castle, regardless what state is in, is the bomb! much like when i visit home (chicago), wc is my first stop i ... (833 characters truncated) ... l, but hey, it is vegas. all in all i'm geeked that there is a taste of home now only 4 1/2 hours away by car and i try to take it as often as i can!", 5.0, '2016-08-20'),
#  ('8qjziu4_xhanzyruaeszkg', '2crbr_sjuxfksgizjgyeta', 'dkdapyvfdsnysnoso6nyla', 89109, 'it was just what i expected. the line was long but they served us fast. the burgers were fresh and hot. the order was made correctly and the environment was cleaned.', 5.0, '2015-12-30'),
#  ('icsqbprzjayncs-wg04qvq', '15umvtulk7srjr2tsajfqg', 'dkdapyvfdsnysnoso6nyla', 89109, 'overpriced cold burgers, your better off buying them at the store in the frozen food section. the long lines and mass produced burgers by the hundred ... (25 characters truncated) ... hat is not worth the price. hopefully white castle will open a few more in vegas with the real menu that is not charging an arm and leg for a burger.', 1.0, '2015-04-27'),
#  ('5amz2kcduzfvtekdihpsqq', 'wm7o0fja6nihl-m6frfgyq', 'dkdapyvfdsnysnoso6nyla', 89109, 'no i\'m not high. i don\'t think. no...i\'m not. \n\nsome friends who are strictly from the west coast came to visit vegas and wanted to eat at white ... (286 characters truncated) ... em. \n\ni know this place is popular, and my review won\'t matter, but next time i hit the strip, i\'ll stop by and get my "little" white castle fix!', 4.0, '2017-01-24'),
#  ('6hh99lrhfchgnubswdmzcw', 'cjbo0rhemlzonuy-_xkdyg', 'dkdapyvfdsnysnoso6nyla', 89109, "judge me, i'm giving 4 stars to a fast food. white castle is rare on the west coast and that's partly what makes it so good. the closest thing to the ... (461 characters truncated) ... egory all on its own of fast food sliders. the employees are all really friendly. the food is good and soaks up all the alcohol you've been drinking.", 4.0, '2015-12-16'),
#  ('n8m7dj7ufbxbazdt1posfw', '0clrptuqxt5dvybsadoqsg', 'dkdapyvfdsnysnoso6nyla', 89109, "we actually ate here on valentine's!  haha.  i wasn't sure if i'd had wc before, and my wife hadn't.  plus we ate at andre's the night before, so wth ... (637 characters truncated) ... y that you either need to grow up on it or be stoned to enjoy it.  we downed a few drinks beforehand, but i think i would still enjoy the food sober.", 4.0, '2015-02-18'),
#  ('s_gg-gp7sadv2ntlr6p_sa', 'nxxociolnhtshv-caj8g4g', 'dkdapyvfdsnysnoso6nyla', 89109, "if this wasn't in a part of the strip that is a little...questionable, then i think the overall vibe would be a bit better. anyway. the food is cheap. it's tasty. it's a novelty. go for the experience. try the onion strips. mmmm.", 4.0, '2017-07-21'),
#  ('p8gvc3kgbuau_wyri0fcna', 'dgmoxfj_deoren7oskte-w', 'dkdapyvfdsnysnoso6nyla', 89109, "harold & kumar go to white castle!\n\ni have seen this movie at least 5 times and i have been eating the frozen cheeseburgers for years!!!  you can a ... (1746 characters truncated) ...  i come back, i'll try the chicken rings and loaded fries.   menu is simple and easy to order from, and for drinks they have a fountain soda machine.", 4.0, '2015-04-20'),
#  ('zsnptvfzl_zavttdv7zhjq', 'lvsp44z5nh1w-isvzxnpsg', 'dkdapyvfdsnysnoso6nyla', 89109, "i grew up eating white castle in nyc since i was a toddler.  i live in los angeles now and when  go back to visit family in ny, i usually grab a few  ... (783 characters truncated) ... till taste similar to those terrible frozen ones you buy at the supermarket.   it's too bad because i was really excited to have a location out west.", 2.0, '2016-11-11'),
#  ('q8evqvzqmkqnmdnocplm0w', '06g5pqdyhslic43_1mmygq', 'dkdapyvfdsnysnoso6nyla', 89109, "vegas valentine's day adventure!\n\nfebruary 15, 2015\n\nso lucky to have such an amazing boyfriend who planned the whole trip for us to eat in vegas ... (379 characters truncated) ... and more the very next hour. \n\noverall, spent $46 bucks on the food for two! \n\nyes, he is perfect because we share our fatty side with each other", 5.0, '2015-03-02'),
#  ('vda5sfcl0kmqatbuw6lphw', 'sp_nvqmidesvn_uvwcfmjw', 'dkdapyvfdsnysnoso6nyla', 89109, "the burgers are gross. but it's super clean, and the chicken rings are.. okay if you've got the munchies", 3.0, '2015-10-30')]

# %%
# %%sql
# SELECT DISTINCT zipcode FROM review_fact_table
#  (85303,),
#  (28730,),
#  (15342,),
#  (15231,),
#  (85256,),
#  (15035,),
#  (15026,),
#  (15131,),
#  (15148,),
#  (15135,),
#  (44055,),
#  (44028,),
#  (15075,),
#  (44255,),
#  (44021,),
#  (15332,),
#  (61859,),
#  (44313,),
#  (19464,),
#  (89142,),
#  (85208,),
#  (15218,),
#  (15133,),
#  (85001,),
#  (28173,),
#  (44264,),
#  (44072,),
#  (61880,),
#  (15129,),
#  (85036,),
#  (15018,),
#  (89124,),
#  (44132,),
#  (85326,),
#  (85073,),
#  (85087,),
#  (85378,),
#  (85005,),
#  (85064,),
#  (85307,),
#  (85264,),
#  (44050,),
#  (15636,),
#  (44065,),
#  (15339,),
#  (15049,),
#  (15056,),
#  (85252,),
#  (15688,),
#  (61873,),
#  (27863,),
#  (15076,),
#  (15045,),
#  (89111,),
#  (85373,),
#  (15112,),
#  (44233,),
#  (45612,),
#  (15030,),
#  (85280,),
#  (15034,),
#  (15046,),
#  (15104,),
#  (28130,),
#  (15240,),
#  (89152,),
#  (28284,),
#  (19362,),
#  (89019,),
#  (15088,),
#  (15031,),
#  (44045,),
#  (15277,),
#  (89114,),
#  (44210,),
#  (15637,),
#  (15678,),
#  (44234,),
#  (15142,),
#  (28070,),
#  (15057,),
#  (61849,),
#  (15051,),
#  (15067,),
#  (85287,),
#  (15055,),
#  (15632,),
#  (15038,),
#  (85361,),
#  (15301,),
#  (15367,),
#  (15140,),
#  (61864,),
#  (44096,),
#  (27278,)]

# %% [markdown]
# # Try SQL

# %%
# %%sql
# SELECT count(r.review_id) FROM business
# JOIN review_fact_table r on r.business_id = business.b_id
# where business.state = 'nv'
# Out:
# Done.
# [(772691,)]

# %%
# %%sql
# SELECT count(b_id) from business
# where state = 'pa'
# Out:
# Done.
# [(2641,)]

# %%
# %%sql
# SELECT count(user_id) from users
# Out:
# Done.
# [(1183362,)]

# %%
# %%sql
# SELECT count(avg_income) from income
# Out:
# Done.
# [(4742,)]

# %%
# %%sql
# SELECT distinct state from income
# Out:
# Done.
# [('pa',), ('nc',), ('oh',), ('il',), ('az',), ('nv',)]

# %%
# %%sql
# SELECT COUNT(distinct business.b_id) FROM business, review_fact_table r WHERE r.zipcode = business.postal_code
# Out:
# Done.
# [(20678,)]

# %%
# %%sql
# SELECT COUNT(distinct business.b_id) FROM business
# Out:
# Done.
# [(21380,)]

# %%
# %%sql
# SELECT distinct business.b_id FROM business, review_fact_table r WHERE r.zipcode != business.postal_code
# Out:
# Done.

# %%
# %%sql
# SELECT categories FROM business WHERE categories LIKE '%fast food%' LIMIT 50

# %%
# %%sql
# SELECT distinct income_id FROM review_fact_table

# %%
# %%sql
# SELECT * FROM business LIMIT 50

# %%
# %%sql
# SELECT business_id FROM review_fact_table LIMIT 10

# %%
# %%sql
# SELECT distinct business.state FROM business, review_fact_table
# WHERE review_fact_table.business_id = business.b_id LIMIT 50

# %%
#import pandas as pd
#sql = "SELECT * FROM TABLE"

#df = pd.read_sql(sql, cnxn)
