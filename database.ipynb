# %% [markdown]
# # Create database structure
# 1. include users, business, income, review fact table
# 2. star schema

# %%
def create_database(conn):
    c = conn.cursor()

    c.execute('''DROP TABLE IF EXISTS business''')
    c.execute('''DROP TABLE IF EXISTS users''')
    c.execute('''DROP TABLE IF EXISTS income''')
    c.execute('''DROP TABLE IF EXISTS review_fact_table''')
    
    c.execute('''
            CREATE TABLE users(
                user_id VARCHAR PRIMARY KEY, 
                review_count int,
                yelping_since DATE,
                average_stars REAL,
                UNIQUE(user_id))''')
    
    c.execute('''
            CREATE TABLE business(
                b_id VARCHAR,
                categories text,
                city text,
                is_open int,
                latitude REAL,
                longitude REAL,
                name text,
                postal_code REAL,
                pricerange int,
                review_count int,
                b_stars REAL,
                state text,
                PRIMARY KEY(b_id)
                UNIQUE(b_id) )''')
    
    c.execute('''
            CREATE TABLE income(
                county text,
                state text, 
                avg_income REAL,
                PRIMARY KEY(county, state))''')
    
    
    #create fact_table
    c.execute('''
        CREATE TABLE review_fact_table(
            review_id VARCHAR,
            user_id VARCHAR,
            business_id VARCHAR,
            review text,
            b_state text,
            r_stars REAL,
            r_date DATE,
            PRIMARY KEY (review_id),
            FOREIGN KEY (user_id) REFERENCES users(user_id), 
            FOREIGN KEY (business_id, b_state) REFERENCES business(b_id, state))''')
    # Commit changes
    conn.commit()
# Create the database   
create_database(conn)

# %% [markdown]
# # Populate database
# 1. Users table from user_data.csv
# 2. Business table from business_data.csv
# 3. income table from income_data.csv
# 4. review_fact_table table from review_data2.csv

# %%
def populate_database(conn):    
    #reader = csv.reader(open('review_data2.csv', encoding='latin1'))
    reader = csv.reader(open('data/business_data.csv', encoding='latin1'))

    next(reader, None)
    for row in reader:
        row = [item.lower() for item in row]   
        # business table
        try:
            c.execute('''
                INSERT INTO business(b_id,
                                    categories,
                                    city,
                                    is_open,
                                    latitude,
                                    longitude,
                                    name,
                                    postal_code,
                                    pricerange,
                                    review_count,
                                    b_stars,
                                    state)VALUES(?,?,?,?,?,?,?,?,?,?,?,?)''',
                      (row[0],row[1],row[2],row[3],row[4],row[5],row[6],row[7],row[8],row[9],row[10],row[11]))
        except sqlite3.Error as e:
            print("business, insert error:", e.args[0])
    conn.commit()
              
   



    # Income table    
    reader = csv.reader(open('data/income_data.csv', encoding='latin1'))
    next(reader, None)
    for row in reader:
        row = [item.lower() for item in row]
        # column 0 = county, column 1 = income, column 2 = state
        try:
            c.execute('''
                INSERT INTO income(county,state, avg_income)VALUES(?,?,?)
            ''',(row[0],row[2],row[1]))
        except sqlite3.Error as e:
            print("income, insert error:", e.args[0])
    conn.commit()
    
    
    
    
    
    
     # user table : col 0 = average_stars, col 1 = review_count, col 2 = user_id, col 3 = yelping_since   
    reader = csv.reader(open('data/user_data.csv', encoding='latin1'))
    next(reader, None)
    for row in reader:
        row = [item.lower() for item in row]
        try:
            c.execute('''
                INSERT INTO users(user_id, review_count, yelping_since, average_stars)VALUES(?,?,?,?)
                ''', (row[2], row[1], row[3], row[0]))
        except sqlite3.Error as e:
            print("users, insert error:", e.args[0])
    conn.commit()
                      
                      
                      
                      
    
                      
                      
                      
                      
    # review fact table
    # col 0 = Unnamed: 0, col 1 = Unnamed: 0.1, col 2 = business_id	
    # col 3 = date, col 4 = review_id, col 5 = stars, col 6 = text, col 7 = user_id
    reader = csv.reader(open('data/review_data2.csv', encoding='latin1'))
    next(reader, None)
    for row in reader:
        row = [item.lower() for item in row]
        try:
            c.execute('''
                INSERT INTO review_fact_table(review_id, 
                                                user_id, 
                                                business_id,
                                                review,
                                                b_state, 
                                                r_stars, 
                                                r_date) VALUES(?,?,?,?,?,?,?)''', 
                      (row[4], row[7], row[2], row[6], row[0], row[5], row[3]))
        except sqlite3.Error as e:
            print("review_fact_table, insert error:", e.args[0])
    conn.commit()

# %%
# create_database(conn)
populate_database(conn)

# %%
for t in['business', 'income','users','review_fact_table']:
    print('%s:'%t)
    print(pandas.read_sql_query("SELECT * FROM %s"%t, conn), '\n')
# Out:
# reviews:
#               id   review_id business_id                    date  \
# 0              1  2017-06-03          16  jqsnfozdpxpmourswcg1vq
# 1              2  2015-03-26          17  jqsnfozdpxpmourswcg1vq
# 2              3  2012-12-30          18  jqsnfozdpxpmourswcg1vq
# 3              4  2009-01-12          19  jqsnfozdpxpmourswcg1vq
# 4              5  2015-07-11          20  jqsnfozdpxpmourswcg1vq
# 5              6  2015-05-27          21  jqsnfozdpxpmourswcg1vq
# 6              7  2015-02-28          22  jqsnfozdpxpmourswcg1vq
# 7              8  2010-04-05          23  jqsnfozdpxpmourswcg1vq
# 8              9  2015-05-22          24  jqsnfozdpxpmourswcg1vq
# 9             10  2011-06-15          25  jqsnfozdpxpmourswcg1vq
# 10            11  2017-03-12          26  jqsnfozdpxpmourswcg1vq
# 11            12  2016-12-19          27  jqsnfozdpxpmourswcg1vq
# 12            13  2011-08-10          28  jqsnfozdpxpmourswcg1vq
# 13            14  2013-06-17          29  jqsnfozdpxpmourswcg1vq
# 14            15  2015-11-03          30  jqsnfozdpxpmourswcg1vq
# 15            16  2017-07-08          31  jqsnfozdpxpmourswcg1vq
# 16            17  2015-09-22          32  jqsnfozdpxpmourswcg1vq
# 17            18  2012-10-08          33  jqsnfozdpxpmourswcg1vq
# 18            19  2015-12-28          34  jqsnfozdpxpmourswcg1vq
# 19            20  2009-11-18          35  jqsnfozdpxpmourswcg1vq
# 20            21  2012-07-29          36  jqsnfozdpxpmourswcg1vq
# 21            22  2016-06-19          37  jqsnfozdpxpmourswcg1vq
# 22            23  2012-08-23          38  jqsnfozdpxpmourswcg1vq
# 23            24  2009-06-25          39  jqsnfozdpxpmourswcg1vq
# 24            25  2008-10-06          40  jqsnfozdpxpmourswcg1vq
# 25            26  2015-03-17          41  jqsnfozdpxpmourswcg1vq
# 26            27  2014-04-22          42  jqsnfozdpxpmourswcg1vq
# 27            28  2016-05-07          43  jqsnfozdpxpmourswcg1vq
# 28            29  2014-05-03          44  jqsnfozdpxpmourswcg1vq
# 29            30  2014-05-29          45  jqsnfozdpxpmourswcg1vq
# ...          ...         ...         ...                     ...
# 10       kznhtw1qido_9gx6sdqpjw  5.0
# 11       hwrtvn3lc-rwn6udv4wjzq  5.0
# 12       gieb_a-m9hux521wqnbl8w  4.0
# 13       gki4i6qocigaycwv1_0zzq  2.0
# 14       orhwg2mmcznwfkfjhkvuha  3.0
# 15       qxwku_ob3fcj9vczfuzwwg  1.0
# 16       5ntaw5ewxk595kp4ynnisg  2.0
# 17       ai6o4uqqdqnjo7gfz6jbka  3.0
# 18       zrvsd7psypolii3gp4-uhw  5.0
# 19       p7oqbxtjwmin_xyohb6tfw  2.0
# 20       ukpjwnetf5wghgrsxmprwa  4.0
# 21       mt6u5lujk_ziciqux92sea  4.0
# 22       yxaxextdwtdmheb14rgfrg  3.0
# 23       ue6ts-ga9khywe76lel1kg  4.0
# 24       wstyqsynyud7xpwfrgwi0g  4.0
# 25       g9yv-m3kvoqfpyjhcjurdg  3.0
# 26       fk8oi26dahqfot46t_sxwg  1.0
# 27       ld06ewr5yyutwxud9ude0q  5.0
# 28       cxvx2fd73kw--ruzxl_rva  4.0
# 29       jjau6pbkkygl15p-5zfg3a  3.0
# ...                         ...  ...
# 3123330  hzd4iwgacqelmbzgpkcioa  4.0
# 3123331  plg7kmqabivs3yxyy88jgq  4.0
# 3123332  ttryca5ytaj_hktwm9cp-a  5.0
# 3123333  cx5k3fy0f2x7fzi0w1qdta  4.0
# 3123334  xvkqukhwipkevs7zvdn0ew  4.0
# 3123335  onlrvlccqg03jyqf_bgvpw  3.0
# 3123336  46d_tk-oiqs-jt3u8vn0pg  3.0
# 3123337  tmhcolqayihtwdqlgtv9fq  2.0
# 3123338  ssid6meyfbvvjfv-ozuw-g  3.0
# 3123339  bp3zajpim_asklxvzeag-q  4.0
# 3123340  idyg-t6t6ohyvk3boa42lw  4.0
# 3123341  4orekdk9f3ewzb9pmkj_qw  5.0
# 3123342  5jv4r1kiwern3jviymoc8a  3.0
# 3123343  _b815arwo9hriwjtqj_f_g  5.0
# 3123344  kqpavytos4-ntaw4czl3sa  5.0
# 3123345  kyyva_i5rk8oeda8se-nyw  5.0
# 3123346  hht_kvtcn3yyw3vbi55k3q  4.0
# 3123347  wxeo3e-7ndzpawrip828qa  5.0
# 3123348  rywg5rjmd4_qbsitefxfha  2.0
# 3123349  -kj48akzcoz6n6uvmlve_w  4.0
# 3123350  932nzmvxvvza5ulaet6f-q  4.0
# 3123351  m-4duiwmoj0vndqgrkrgjw  5.0
# 3123352  sfktykjtwlnhkqbzr3zoeq  1.0
# 3123353  o40pvpxb_th3z1tcux1ega  4.0
# 3123354  tcbd1pxrgj3ytbqb2q4nsq  5.0
# 3123355  jrmc2esqsyyhcmsmlwyx-q  3.0
# 3123356  vw304lsvkz5kgxhqt_v3wa  5.0
# 3123357  8giktiy-hrdgg7fnrnldng  2.0
# 3123358  3bcbmgjbhro-rzqujm0xxg  5.0
# 3123359  zvqfgeqvivldpuc4hjtubw  5.0
#
#                                                    user_id
# 0        this place is horrible, we were so excited to ...
# 1        for being fairly "fast" food.. pei wei (pronou...
# 3      ['sports wear', 'outlet stores', 'department s...     tuscola        1
# 4                            ['restaurants', 'barbeque']      urbana        0
# 5                                ['restaurants', 'thai']   champaign        0
# 6      ['ice cream & frozen yogurt', 'food', 'do-it-y...   champaign        1
# 7                    ['shopping', 'lingerie', 'fashion']   champaign        1
# 8      ['burgers', 'sports bars', 'american (traditio...       savoy        1
# 9                                  ['bars', 'nightlife']   champaign        1
# 10                            ['italian', 'restaurants']   champaign        0
# 11                       ['grocery', 'food', 'bakeries']     mahomet        1
# 12                 ['food', 'ice cream & frozen yogurt']   champaign        0
# 13     ['fashion', 'used', 'vintage & consignment', '...   champaign        1
# 14                 ['thai', 'restaurants', 'sushi bars']      urbana        1
# 15     ['bars', 'nightlife', 'restaurants', 'american...   champaign        1
# 16     ['nightlife', 'bars', 'pubs', 'restaurants', '...   champaign        0
# 17     ['fish & chips', 'restaurants', 'american (tra...   champaign        1
# 18     ['coffee roasteries', 'brewing supplies', 'cof...   champaign        1
# 19     ['hair salons', 'hair stylists', 'beauty & spas']   champaign        1
# 20                         ['restaurants', 'tapas bars']   champaign        0
# 21               ['fast food', 'burgers', 'restaurants']      urbana        1
# 22     ['shopping', 'sporting goods', 'accessories', ...   champaign        1
# 23     ['shopping', 'home & garden', 'furniture store...   champaign        1
# 24     ["children's clothing", 'accessories', 'pet st...   champaign        0
# 25                  ['restaurants', 'food', 'fast food']      urbana        1
# 26                              ['food', 'coffee & tea']      urbana        1
# 27                            ['restaurants', 'buffets']     tuscola        0
# 28                            ['restaurants', 'mexican']   champaign        1
# 29     ['american (traditional)', 'restaurants', 'kar...   champaign        1
# ...                                                  ...         ...      ...
# 61704  ['shopping', 'health & medical', 'eyewear & op...     phoenix        0
# 61705                   ['beauty & spas', 'hair salons']     phoenix        1
# 61706  ['shopping', 'arts & entertainment', 'art gall...     phoenix        1
# 61707          ['beauty & spas', 'tanning', 'skin care']     phoenix        1
# 61708  ['music venues', 'arts & entertainment', 'rest...       tempe        0
# 61709                         ['restaurants', 'burgers']     phoenix        1
# 61710  ['accessories', "men's clothing", 'shopping', ...     phoenix        1
# 61711  ['local services', 'mobile phones', 'shopping'...    glendale        1
# 61712  ['coffee & tea', 'donuts', 'restaurants', 'bre...    surprise        1
# 61713  ['shopping', 'local services', 'sewing & alter...     phoenix        1
# 61714  ['hair removal', 'nail salons', 'makeup artist...     phoenix        1
# 61715          ['mediterranean', 'greek', 'restaurants']        mesa        0
# 61716                        ['japanese', 'restaurants']       tempe        1
# 61717  ['spray tanning', 'beauty & spas', 'gyms', 'ma...     phoenix        1
# 61718  ['hotels & travel', 'event planning & services...     phoenix        1
# 61719  ['diners', 'mexican', 'tex-mex', 'breakfast & ...     phoenix        1
# 61720  ['furniture stores', 'department stores', 'hom...    goodyear        1
# 61721  ['vegetarian', 'ethnic food', 'restaurants', '...       tempe        1
# 61722        ['florists', 'flowers & gifts', 'shopping']       tempe        0
# 61723                                    ['restaurants']  scottsdale        0
# 61724  ['american (traditional)', 'burgers', 'restaur...        mesa        1
# 61719  33.640007 -112.047222       85022           1            68    3.5
# 61720  33.450818 -112.356788       85338           1             5    3.0
# 61721  33.377432 -111.906919       85281           1            97    4.0
# 61722  33.421396 -111.908341       85281           2            13    3.5
# 61723  33.567382 -111.925930       85253           2            15    3.5
# 61724  33.407126 -111.873495       85202           1            35    3.5
# 61725  33.390236 -111.789758       85204           1            35    4.0
# 61726  33.509667 -112.071740       85012           2            58    3.5
# 61727  33.639496 -112.276363       85351           1            34    3.5
# 61728  33.391896 -111.788425       85204           2             3    4.5
# 61729  33.638479 -112.067228       85022           2           157    4.5
# 61730  33.456435 -112.394234       85338           1            54    4.0
# 61731  33.600876 -112.287774       85351           1            50    3.5
# 61732  33.637932 -112.188525       85308           2            18    1.5
# 61733  33.637750 -112.189824       85308           1            12    5.0
#
#       state
# 0        il
# 1        il
# 2        il
# 3        il
# 4        il
# 5        il
# 6        il
# 7        il
# 8        il
# 9        il
# 10       il
# 11       il
# 12       il
# 13       il
# 14       il
# 15       il
# 16       il
# 17       il
# 18       il
# 19       il
# 20       il
# 21       il
# 22       il
# 23       il
# 24       il
# 25       il
# 26       il
# 27       il
# 28       il
# 29       il
# ...     ...
# 61704    az
# 61705    az
# 61706    az
# 61707    az
# 61708    az
# 61709    az
# 61710    az
# 61711    az
# 61712    az
# 61713    az
# 61714    az
# 61715    az
# 61716    az
# 61717    az
# 61718    az
# 61719    az
# 61720    az
# 61721    az
# 61722    az
# 61723    az
# 61724    az
# 61725    az
# 61726    az
# 61727    az
# 61728    az
# 61729    az
# 61730    az
# 61731    az
# 61732    az
# 61733    az
#
# [61734 rows x 12 columns]

# %% [markdown]
# # Initiate database & SQL

# %%
# !pip install ipython-sql
# %reload_ext sql
# %sql sqlite:///yelp.db
# Out:
# Requirement already satisfied: ipython-sql in /Users/zhangtong/anaconda/lib/python3.6/site-packages
# Requirement already satisfied: sqlalchemy>=0.6.7 in /Users/zhangtong/anaconda/lib/python3.6/site-packages (from ipython-sql)
# Requirement already satisfied: prettytable in /Users/zhangtong/anaconda/lib/python3.6/site-packages (from ipython-sql)
# Requirement already satisfied: sqlparse in /Users/zhangtong/anaconda/lib/python3.6/site-packages (from ipython-sql)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /Users/zhangtong/anaconda/lib/python3.6/site-packages (from ipython-sql)
# Requirement already satisfied: ipython>=1.0 in /Users/zhangtong/anaconda/lib/python3.6/site-packages (from ipython-sql)
# Requirement already satisfied: six in /Users/zhangtong/anaconda/lib/python3.6/site-packages (from ipython-sql)
# 'Connected: None@yelp.db'

# %% [markdown]
# # Try SQL

# %%
# %%sql
# SELECT count(r.review_id) FROM business
# JOIN review_fact_table r on r.business_id = business.b_id
# where business.state = 'nv'
# Out:
# Done.
# [(1353555,)]

# %%
# %%sql
# SELECT d.director_name, d.director_id,count(d.director_id) as count From fact_table
# join directors d on d.director_id = fact_table.director_id
# join movies m on m.movie_id = fact_table.movie_id
# where m.title_year >=2007
# group by d.director_id
# HAVING count(m.movie_title)>=5
# order by count(m.movie_title)DESC

# %%
# %%sql
# SELECT count(b_id) from business
# where state = 'pa'
# Out:
# Done.
# [(6002,)]

# %%
# %%sql
# SELECT count(user_id) from users
# Out:
# Done.
# [(1183362,)]

# %%
# %%sql
# SELECT count(avg_income) from income
# Out:
# Done.
# [(154,)]

# %%
# %%sql
# SELECT distinct state from income
# Out:
# Done.
# [('arizona',),
#  ('pennsylvania',),
#  ('nevada',),
#  ('north carolina',),
#  ('ohio',),
#  ('illinois',)]
